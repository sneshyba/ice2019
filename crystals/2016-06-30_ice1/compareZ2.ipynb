# %%
# Generic imports
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
case15 = np.loadtxt('case1.5/Segments2roughnessZ2.txt')
case11 = np.loadtxt('case1.1/Segments1roughnessZ2.txt')
case1 = np.loadtxt('case1 (calibration)/Segments1roughnessZ2.txt')

# %%
plt.figure()
markersize = 7
plt.plot(case1[:,0],case1[:,1],'ok',markersize=markersize, label=r'case 1, $\sigma=.08$')
plt.plot(case11[:,0],case11[:,1],'ob',markersize=markersize, label=r'case 1.1, $\sigma=.09, .26$')
plt.plot(case15[:,0],case15[:,1],'og',markersize=markersize, label='case 1.5, $\sigma=.25, .4$')
plt.grid(True)
plt.xlabel('$Z^2$')
plt.ylabel(r'$ln(\rho)$')
plt.legend()
plt.xlim([-.02,.6])
plt.ylim([-8,0])
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# (-8, 0)
