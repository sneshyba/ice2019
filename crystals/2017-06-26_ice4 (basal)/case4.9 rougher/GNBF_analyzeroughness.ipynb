# %%
# Generic imports
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import PIL
import os
from scipy.special import gamma
import scipy.optimize as optimization

# Local imports
import sys
sys.path.append('../../../')
import stlstuff as sls
import imagestuff as ims
import statstuff as sts

# %%
# %matplotlib notebook

# %%
# Graphics parameters
fontsize = 10
linewidth = 2
matplotlib.rcParams.update({'font.size': fontsize})

# %%
# Set defaults for the analysis
accumlist = [] # This will be all segments unless overridden 

# Only turn this on if we want PDF in terms of Z^2
IwantZ2intervals = True
Iwantlogrintervals = False

if (IwantZ2intervals):
    numforZ2hist = 25
    Z2minforhist = 1e-4; #print(Z2minforhist)
    rmaxforZ2hist = 0.1; Z2maxforhist = 1/(1-rmaxforZ2hist)**2-1; print(Z2maxforhist)
    Z2maxforhist = 0.23; #print(Z2maxforhist)
    
if (Iwantlogrintervals):
    numforhist = 70
    rminforhist = 1e-7
    rmaxforhist = .6
# Out:
# 0.23456790123456783

# %%
# Specify the file we want to analyze (and output file name)
pwd = os.getcwd()
print(pwd)
startpos = pwd.find('crystals/')
case = pwd[startpos+9:]; print(case)
Segmentroot='Segments2'
# Out:
# /Users/nesh/Documents/repositories/ice4/crystals/2017-06-26_ice4 (basal)/case4.9 rougher
# 2017-06-26_ice4 (basal)/case4.9 rougher

# %%
# Derivative names
Compressedfilename = Segmentroot+'retrieved.npz'; print (Compressedfilename)
Roughnessfile = Segmentroot+'roughness.jpg'; print(Roughnessfile)
RoughnessZ2file = Segmentroot+'roughnessZ2.jpg'; print(RoughnessZ2file)
RoughnessZ2datafile = Segmentroot+'roughnessZ2.txt'; print(RoughnessZ2datafile)
Roughnessdatafile=Segmentroot+'roughness.txt'; print(Roughnessdatafile)
Roughnessfitfile=Segmentroot+'roughnessfit.txt'; print(Roughnessfitfile)
# Out:
# Segments2retrieved.npz
# Segments2roughness.jpg
# Segments2roughnessZ2.jpg
# Segments2roughnessZ2.txt
# Segments2roughness.txt
# Segments2roughnessfit.txt

# %%
# Get the retrieved surface
npzfile = np.load(Compressedfilename)
imageroot = np.array_str(npzfile['imageroot'])
dx,dy,cA,cB,cC,cD,Filename = ims.getc2('', 'SEMimages/', imageroot)
print("dx and dy", dx, dy)
# Out:
# dx and dy 0.6614583 0.6614583

# %%
# Setting up windows for where the data are, and the accumulation array
nx1list = npzfile['nx1list']
nx2list = npzfile['nx2list']
ny1list = npzfile['ny1list']
ny2list = npzfile['ny2list']
solution = npzfile['solution']
nsegments = len(nx1list)
if len(accumlist)==0:
    accumlist = [i for i in range(nsegments)] 
print('Completed',case) #Prints loading but I wanted to know when it was done.
# Out:
# Completed 2017-06-26_ice4 (basal)/case4.9 rougher

# %%
# Graph the segments
im = PIL.Image.open(Filename)
ny_im,nx_im = np.shape(im)
draw = PIL.ImageDraw.Draw(im)
for i in range(nsegments):
    nx1 = nx1list[i]
    nx2 = nx2list[i]
    ny1 = ny1list[i]
    ny2 = ny2list[i]
    ims.myrectangle(draw,(nx1,ny1),(nx2,ny2),2)
# fig, ax = plt.subplots()
# ax.set_title(Compressedfilename,fontsize=fontsize*0.9)
# ax.axes.get_xaxis().set_visible(False)
# ax.axes.get_yaxis().set_visible(False)
# plt.show(im,cmap = 'Greys_r', vmin = 0,vmax = 255)
im.show() # This shouldn't be necessary but there seems to be a bug with plt.show

# %%
# Get the histogram as a function of log(r)
if (Iwantlogrintervals):
    newrbins=np.geomspace(rminforhist,rmaxforhist,num=numforhist)
    hbins_total, rbinsW = sts.makehistogram(\
                                 nsegments,nx1list,nx2list,ny1list,ny2list,dx,dy,solution,\
                                 accumlist, newrbins)

# %%
# Analysis of this histogram
if (Iwantlogrintervals): 
    # Get the best Weibull fit
    x0 = np.array([0.1])
    fsolution, fsolutionerror = optimization.curve_fit(sts.pGaussianr, rbinsW, hbins_total, x0)
    best_sigmaG = fsolution[0]; 
    print('Gaussian: best_sigma = ', best_sigmaG)

    # Get the best Weibull fit
    x0 = np.array([0.1,1.0])
    fsolution, fsolutionerror = optimization.curve_fit(sts.pWeibullr, rbinsW, hbins_total, x0)
    best_sigmaW = fsolution[0]; 
    print('Weibull: best_sigma = ', best_sigmaW)
    best_eta = fsolution[1]
    print('Weibull: best_eta = ', best_eta)

    # Get the best match for a two-gaussian fit
    x0 = np.array([0.09,0.24,.5])
    fsolution, fsolutionerror = optimization.curve_fit(sts.bimodalfunc, rbinsW, hbins_total, x0)
    best_sigma1 = fsolution[0]
    best_N1 = 1-fsolution[2]
    print('Bimodal: best_sigma1,N1 = ', best_sigma1,best_N1)
    best_sigma2 = fsolution[1]
    best_N2 = fsolution[2]
    print('Bimodal: best_sigma2,N2 = ', best_sigma2,best_N2)
    
        # Get the best-fit distributions
    hbins_gauss = sts.pWeibullr(rbinsW, best_sigmaG, 1)
    R2_G = sts.R_squar(hbins_total,hbins_gauss)
    print('R^2 (Gauss) = ', R2_G)
    hbins_bestfit = sts.pWeibullr(rbinsW, best_sigmaW, best_eta)
    R2_W = sts.R_squar(hbins_total,hbins_bestfit)
    print('R^2 (Weibull) = ', R2_W)
    hbins_bimodal = sts.bimodalfunc(rbinsW, best_sigma1, best_sigma2, best_N2)
    R2_B = sts.R_squar(hbins_total,hbins_bimodal)
    print('R^2 (Bimodal) = ', R2_B)
    
    # Labels for graph
    label_obs = 'obs'
    label_Gauss = 'Gaussian: ' \
                    +'$\sigma$='+str(np.round(best_sigmaG*100)/100) + '\n'\
                    +'$R^2=$'+str(np.round(R2_G*1000)/1000) 
    label_Weibull = 'Weibull: ' \
                    +'$\sigma_W$='+str(np.round(best_sigmaW*100)/100) \
                    +', ' +'$\eta_W$='+str(np.round(best_eta*100)/100) + '\n'\
                    +'$R^2=$'+str(np.round(R2_W*1000)/1000) 

    label_bimodal = 'Bimodal: ' + '\n'\
                    +'$\sigma_1$='+str(np.round(best_sigma1*100)/100) \
                    +', '+'$N_1$='+str(np.round(best_N1*100)/100) + '\n'\
                    +'$\sigma_2$='+str(np.round(best_sigma2*100)/100) \
                    +', '+'$N_2$='+str(np.round(best_N2*100)/100) + '\n'\
                    +'$R^2=$'+str(np.round(R2_B*1000)/1000) 

    # Graph
    plt.figure()
    plt.semilogx(rbinsW,hbins_total,'ok',markersize=5, label=label_obs)
    plt.semilogx(rbinsW,hbins_gauss,'--g',linewidth=2, label=label_Gauss)
    plt.semilogx(rbinsW,hbins_bestfit,'-b',linewidth=2, label=label_Weibull)
    plt.semilogx(rbinsW,hbins_bimodal,'-.m',linewidth=2, label=label_bimodal)
    plt.grid(True)
    plt.xlabel(r'$r$',fontsize=fontsize)
    plt.ylabel(r'$r\rho(r)$',fontsize=fontsize)
    plt.legend(loc='upper left')
    plt.title(case,fontsize=fontsize)
    
    plt.savefig(Roughnessfile)
    dummy= [rbinsW,hbins_total]
    np.savetxt(Roughnessdatafile,dummy)
    cfile = open(Roughnessfitfile,'w')
    cfile.write('&Roughness_Best_Fit\n')
    cfile.write(case+'\n\n'+'Gaussian fit:'+'\n')
    cfile.write('   '+'sigma =' +str(best_sigmaG)+'\n')
    cfile.write('   '+'R^2 ='+str(R2_G)+'\n\n'+'Weibull fit:'+'\n')
    cfile.write('   '+'sigma =' +str(best_sigmaW)+'\n')
    cfile.write('   '+'eta =' +str(best_eta)+'\n')
    cfile.write('   '+'R^2 ='+str(R2_W)+'\n\n'+'Bimodal fit:'+'\n')
    cfile.write('   '+'sigma1 =' +str(best_sigma1)+'\n')
    cfile.write('   '+'N1 =' +str(best_N1)+'\n')
    cfile.write('   '+'sigma2 =' +str(best_sigma2)+'\n')
    cfile.write('   '+'N2 =' +str(best_N2)+'\n')
    cfile.write('   '+'R^2 ='+str(R2_B)+'\n')
    cfile.close()

# %%
# Get the histogram as a function of Z2
if (IwantZ2intervals):

    # This calculates a normalized observed PDF as a function of Z^2 (rho(Z^2))
    newZ2bins = np.linspace(Z2minforhist,Z2maxforhist,numforZ2hist)
    newrbins = 1-(1/(newZ2bins+1))**.5

    hbins_total, rbinsW = sts.makehistogram(\
                                 nsegments,nx1list,nx2list,ny1list,ny2list,dx,dy,solution,\
                                 accumlist, newrbins)
    hbins_total = -hbins_total
# Out:
# ../../../imagestuff.py:204: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m, _, _, _ = np.linalg.lstsq(G, z)
# Accumulating ... (36, 35) (1260,) (1260,)
# Accumulating ... (36, 35) (1260,) (2520,)
# Accumulating ... (36, 35) (1260,) (3780,)
# Accumulating ... (36, 35) (1260,) (5040,)
# Accumulating ... (37, 34) (1258,) (6298,)
# Accumulating ... (37, 34) (1258,) (7556,)
# Accumulating ... (38, 33) (1254,) (8810,)
# Accumulating ... (36, 35) (1260,) (10070,)
# Accumulating ... (36, 35) (1260,) (11330,)
# Accumulating ... (36, 35) (1260,) (12590,)
# Accumulating ... (36, 35) (1260,) (13850,)
# Accumulating ... (36, 35) (1260,) (15110,)
# Accumulating ... (37, 35) (1295,) (16405,)
# Accumulating ... (37, 34) (1258,) (17663,)
# Accumulating ... (36, 35) (1260,) (18923,)
# Accumulating ... (36, 35) (1260,) (20183,)
# Accumulating ... (36, 35) (1260,) (21443,)
# Accumulating ... (36, 35) (1260,) (22703,)
# Accumulating ... (36, 35) (1260,) (23963,)
# Accumulating ... (37, 34) (1258,) (25221,)
# Accumulating ... (37, 34) (1258,) (26479,)
# Accumulating ... (36, 35) (1260,) (27739,)
# Accumulating ... (36, 36) (1296,) (29035,)
# Accumulating ... (36, 36) (1296,) (30331,)
# Accumulating ... (36, 35) (1260,) (31591,)
# Accumulating ... (36, 35) (1260,) (32851,)
# Accumulating ... (37, 35) (1295,) (34146,)
# Accumulating ... (38, 34) (1292,) (35438,)
# Accumulating ... (36, 35) (1260,) (36698,)
# Accumulating ... (36, 36) (1296,) (37994,)
# Accumulating ... (36, 36) (1296,) (39290,)
# Accumulating ... (36, 35) (1260,) (40550,)
# Accumulating ... (36, 35) (1260,) (41810,)
# Accumulating ... (36, 35) (1260,) (43070,)
# Accumulating ... (37, 35) (1295,) (44365,)
# Accumulating ... (36, 36) (1296,) (45661,)
# Accumulating ... (36, 36) (1296,) (46957,)
# Accumulating ... (36, 36) (1296,) (48253,)
# Accumulating ... (36, 36) (1296,) (49549,)
# Accumulating ... (36, 35) (1260,) (50809,)
# Accumulating ... (36, 35) (1260,) (52069,)
# Accumulating ... (37, 34) (1258,) (53327,)
# Accumulating ... (36, 36) (1296,) (54623,)
# Accumulating ... (36, 37) (1332,) (55955,)
# Accumulating ... (36, 37) (1332,) (57287,)
# Accumulating ... (36, 36) (1296,) (58583,)
# Accumulating ... (36, 35) (1260,) (59843,)
# Accumulating ... (36, 35) (1260,) (61103,)
# Accumulating ... (38, 34) (1292,) (62395,)
# Accumulating ... (36, 36) (1296,) (63691,)
# Accumulating ... (36, 37) (1332,) (65023,)
# Accumulating ... (36, 37) (1332,) (66355,)
# Accumulating ... (36, 36) (1296,) (67651,)
# Accumulating ... (36, 36) (1296,) (68947,)
# Accumulating ... (36, 35) (1260,) (70207,)
# Accumulating ... (38, 33) (1254,) (71461,)
# Accumulating ... (36, 37) (1332,) (72793,)
# Accumulating ... (36, 38) (1368,) (74161,)
# Accumulating ... (36, 38) (1368,) (75529,)
# Accumulating ... (36, 37) (1332,) (76861,)
# Accumulating ... (36, 36) (1296,) (78157,)
# Accumulating ... (36, 35) (1260,) (79417,)
# Accumulating ... (38, 33) (1254,) (80671,)
# Accumulating ... (36, 38) (1368,) (82039,)
# Accumulating ... (36, 38) (1368,) (83407,)
# Accumulating ... (36, 39) (1404,) (84811,)
# Accumulating ... (36, 38) (1368,) (86179,)
# Accumulating ... (36, 37) (1332,) (87511,)
# Accumulating ... (37, 35) (1295,) (88806,)
# Accumulating ... (38, 33) (1254,) (90060,)
# Accumulating ... (36, 39) (1404,) (91464,)
# Accumulating ... (36, 40) (1440,) (92904,)
# Accumulating ... (36, 41) (1476,) (94380,)
# Accumulating ... (36, 40) (1440,) (95820,)
# Accumulating ... (36, 37) (1332,) (97152,)
# Accumulating ... (36, 36) (1296,) (98448,)
# Accumulating ... (38, 33) (1254,) (99702,)
# Accumulating ... (36, 39) (1404,) (101106,)
# Accumulating ... (36, 39) (1404,) (102510,)
# Accumulating ... (36, 40) (1440,) (103950,)
# Accumulating ... (36, 42) (1512,) (105462,)
# Accumulating ... (36, 42) (1512,) (106974,)
# Accumulating ... (36, 38) (1368,) (108342,)
# Accumulating ... (37, 35) (1295,) (109637,)
# segment, #pts, <r>, sigma = 0 1295 0.005 0.1
# segment, #pts, <r>, sigma = 1 1295 0.01 0.15
# segment, #pts, <r>, sigma = 2 1295 0.008 0.13
# segment, #pts, <r>, sigma = 3 1295 0.008 0.13
# segment, #pts, <r>, sigma = 4 1295 0.012 0.16
# segment, #pts, <r>, sigma = 5 1295 0.008 0.12
# segment, #pts, <r>, sigma = 6 1295 0.007 0.12
# segment, #pts, <r>, sigma = 7 1295 0.006 0.11
# segment, #pts, <r>, sigma = 8 1295 0.01 0.14
# segment, #pts, <r>, sigma = 9 1295 0.007 0.12
# segment, #pts, <r>, sigma = 10 1295 0.007 0.12
# segment, #pts, <r>, sigma = 11 1295 0.007 0.12
# segment, #pts, <r>, sigma = 12 1295 0.007 0.12
# segment, #pts, <r>, sigma = 13 1295 0.008 0.13
# segment, #pts, <r>, sigma = 14 1295 0.007 0.12
# segment, #pts, <r>, sigma = 15 1295 0.007 0.12
# segment, #pts, <r>, sigma = 16 1295 0.01 0.14
# segment, #pts, <r>, sigma = 17 1295 0.007 0.12
# segment, #pts, <r>, sigma = 18 1295 0.01 0.14
# segment, #pts, <r>, sigma = 19 1295 0.009 0.14
# segment, #pts, <r>, sigma = 20 1295 0.009 0.14
# segment, #pts, <r>, sigma = 21 1295 0.006 0.11
# segment, #pts, <r>, sigma = 22 1295 0.006 0.11
# segment, #pts, <r>, sigma = 23 1295 0.006 0.11
# segment, #pts, <r>, sigma = 24 1295 0.007 0.12
# segment, #pts, <r>, sigma = 25 1295 0.009 0.14
# segment, #pts, <r>, sigma = 26 1295 0.013 0.16
# segment, #pts, <r>, sigma = 27 1295 0.015 0.18
# segment, #pts, <r>, sigma = 28 1295 0.006 0.11
# segment, #pts, <r>, sigma = 29 1295 0.005 0.1
# segment, #pts, <r>, sigma = 30 1295 0.006 0.11
# segment, #pts, <r>, sigma = 31 1295 0.006 0.11
# segment, #pts, <r>, sigma = 32 1295 0.007 0.12
# segment, #pts, <r>, sigma = 33 1295 0.008 0.13
# segment, #pts, <r>, sigma = 34 1295 0.008 0.13
# segment, #pts, <r>, sigma = 35 1295 0.004 0.09
# segment, #pts, <r>, sigma = 36 1295 0.005 0.1
# segment, #pts, <r>, sigma = 37 1295 0.005 0.1
# segment, #pts, <r>, sigma = 38 1295 0.007 0.12
# segment, #pts, <r>, sigma = 39 1295 0.006 0.11
# segment, #pts, <r>, sigma = 40 1295 0.007 0.12
# segment, #pts, <r>, sigma = 41 1295 0.007 0.12
# segment, #pts, <r>, sigma = 42 1295 0.004 0.09
# segment, #pts, <r>, sigma = 43 1295 0.005 0.1
# segment, #pts, <r>, sigma = 44 1295 0.005 0.1
# segment, #pts, <r>, sigma = 45 1295 0.005 0.1
# segment, #pts, <r>, sigma = 46 1295 0.004 0.09
# segment, #pts, <r>, sigma = 47 1295 0.006 0.11
# segment, #pts, <r>, sigma = 48 1295 0.007 0.12
# segment, #pts, <r>, sigma = 49 1295 0.005 0.1
# segment, #pts, <r>, sigma = 50 1295 0.005 0.1
# segment, #pts, <r>, sigma = 51 1295 0.005 0.1
# segment, #pts, <r>, sigma = 52 1295 0.004 0.09
# segment, #pts, <r>, sigma = 53 1295 0.004 0.09
# segment, #pts, <r>, sigma = 54 1295 0.005 0.1
# segment, #pts, <r>, sigma = 55 1295 0.007 0.12
# segment, #pts, <r>, sigma = 56 1295 0.005 0.1
# segment, #pts, <r>, sigma = 57 1295 0.006 0.11
# segment, #pts, <r>, sigma = 58 1295 0.005 0.1
# segment, #pts, <r>, sigma = 59 1295 0.004 0.09
# segment, #pts, <r>, sigma = 60 1295 0.005 0.1
# segment, #pts, <r>, sigma = 61 1295 0.006 0.11
# segment, #pts, <r>, sigma = 62 1295 0.008 0.12
# segment, #pts, <r>, sigma = 63 1295 0.004 0.09
# segment, #pts, <r>, sigma = 64 1295 0.005 0.11
# segment, #pts, <r>, sigma = 65 1295 0.007 0.12
# segment, #pts, <r>, sigma = 66 1295 0.005 0.1
# segment, #pts, <r>, sigma = 67 1295 0.005 0.1
# segment, #pts, <r>, sigma = 68 1295 0.006 0.11
# segment, #pts, <r>, sigma = 69 1295 0.008 0.13
# segment, #pts, <r>, sigma = 70 1295 0.003 0.08
# segment, #pts, <r>, sigma = 71 1295 0.006 0.11
# segment, #pts, <r>, sigma = 72 1295 0.007 0.12
# segment, #pts, <r>, sigma = 73 1295 0.01 0.14
# segment, #pts, <r>, sigma = 74 1295 0.006 0.11
# segment, #pts, <r>, sigma = 75 1295 0.006 0.11
# segment, #pts, <r>, sigma = 76 1295 0.008 0.13
# segment, #pts, <r>, sigma = 77 1295 0.004 0.09
# segment, #pts, <r>, sigma = 78 1295 0.004 0.09
# segment, #pts, <r>, sigma = 79 1295 0.005 0.1
# segment, #pts, <r>, sigma = 80 1295 0.007 0.12
# segment, #pts, <r>, sigma = 81 1295 0.008 0.13
# segment, #pts, <r>, sigma = 82 1295 0.009 0.14
# segment, #pts, <r>, sigma = 83 1295 0.009 0.13
# -788.4112485045866

# %%
# Analysis of this histogram
if (IwantZ2intervals):

    # Do some fixing
    ikeep = np.nonzero(hbins_total)
    Z2keep = newZ2bins[ikeep]; #print(Z2keep)
    logrhoZ2 = np.log(hbins_total[ikeep]); #print(logrhoZ2)
    
    # Graph the Z^2 PDF
    plt.figure()
    plt.plot(Z2keep,logrhoZ2,'ob',markersize=10, label='obs')

    # Do some polyfitting
    thisrange = [i for i in range(0,5)]
    p1 = np.polyfit(Z2keep[thisrange],logrhoZ2[thisrange],1)
    best_sigma1 = 1/np.sqrt(-p1[0])
    print(p1,'predicted sigma1 = ', best_sigma1)
    label_sigma1 = '$\sigma_1$='+str(np.round(best_sigma1*100)/100) 
    plt.plot(Z2keep,np.polyval(p1,Z2keep),'g', label=label_sigma1)
    
    n = len(Z2keep)
    thisrange = [i for i in range(8,13)]
    p2 = np.polyfit(Z2keep[thisrange],logrhoZ2[thisrange],1)
    best_sigma2 = 1/np.sqrt(-p2[0])
    print(p2,'predicted sigma2 = ', best_sigma2)
    label_sigma2 = '$\sigma_2$='+str(np.round(best_sigma2*100)/100) 
    plt.plot(Z2keep,np.polyval(p2,Z2keep),'m', label=label_sigma2)
        
    # Annotate
    plt.grid(True)
    plt.xlim([-.01,.15])
    plt.ylim([-9,-1])
    plt.xlabel('$Z^2$')
    plt.ylabel(r'$ln(\rho)$')
    plt.title(case,fontsize=fontsize)
    plt.legend()

    # Save
    np.savetxt(RoughnessZ2datafile,np.transpose([Z2keep,logrhoZ2]))
    plt.savefig(RoughnessZ2file)

    # Reporting
    meanr1 = sts.sigma2meanr(best_sigma1); theta1 = np.arccos(1-meanr1)*180/np.pi; print('t1=',theta1)
    meanr2 = sts.sigma2meanr(best_sigma2); theta2 = np.arccos(1-meanr2)*180/np.pi; print('t2=',theta2)
#     for i in range(len(newrbins)):
#         print(i,newZ2bins[i],newrbins[i])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [-77.46708868  -1.67069126] predicted sigma1 =  0.11361649372895542
# [-49.25538667  -3.08226172] predicted sigma2 =  0.14248630804396836
# t1= 6.45176907002987
# t2= 8.051218542759477

# %%
Z2 = .09; print(Z2)
r = 1-(1/(Z2+1))**.5; print(r)
theta = np.arccos(1-r)*180/np.pi; print(theta)
# Out:
# 0.09
# 0.04217371477884868
# 16.69924423399364
