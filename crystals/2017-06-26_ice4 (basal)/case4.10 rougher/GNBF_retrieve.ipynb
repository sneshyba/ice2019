# %% [markdown]
# This code is designed to retrieve surface information from input A-D image files and given instrument response parameters

# %%
# Generic imports
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import PIL
import copy
from scipy.interpolate import griddata
from scipy.special import gamma
import scipy.optimize as optimization
import os

# Local imports
import sys
sys.path.append('../../../')
import stlstuff as sls
import imagestuff as ims
import facetbrightnessstuff9 as fbs
import f90nml
import gradstuff as gds

# %%
# %matplotlib notebook

# %%
# Specify the file we want to analyze (and output file name)
pwd = os.getcwd()
print(pwd)
startpos = pwd.find('crystals/')
case = pwd[startpos+9:]; print(case)
Segmentnamelistroot = 'Segments'
imageroot = 'figure'
Calibrationfile = '../case4.2 (calibration)/Calibration.nml'
# Out:
# /Users/nesh/Documents/Repositories/ice4/crystals/2017-06-26_ice4 (basal)/case4.10 rougher
# 2017-06-26_ice4 (basal)/case4.10 rougher

# %%
# Derivative names
Compressedfilename = Segmentnamelistroot+'_retrieved.npz'; print (Compressedfilename)
Roughnessfile = Segmentnamelistroot+'_roughness.jpg'; print(Roughnessfile)
Roughnessdatafile = Segmentnamelistroot+'_roughness.txt'; print(Roughnessdatafile)
# Out:
# Segments_retrieved.npz
# Segments_roughness.jpg
# Segments_roughness.txt

# %%
# These are derivative names
Segmentnamelist = Segmentnamelistroot+'.nml'
Segmentfile = Segmentnamelist
SEMSegmentjpgfile =  Segmentnamelistroot+'.jpg'
Retrievedjpgfile =   Segmentnamelistroot+'retrieved.jpg'
Compressedfilename = Segmentnamelistroot+'retrieved'

# %%
# Read the input dataset, including spacing in micrometers
dx,dy,cA,cB,cC,cD,Filename = ims.getc2('', 'SEMimages/', imageroot)
print("Filename, dx and dy", Filename, dx, dy)
# Out:
# Filename, dx and dy SEMimages/figure-D.bmp 0.6201172 0.6201172

# %%
# Show just the image (in case we want to look at it before defining the segments)
im = PIL.Image.open(Filename)
plt.figure()
plt.title(imageroot)
plt.show(im,cmap = 'Greys_r', vmin = 0,vmax = 255)
im.show() # This shouldn't be necessary but there seems to be a bug with plt.show
# Out:
# <img src="data:image/png;base64,..." width="852.75">

# %%
# Extract
Segments=f90nml.read(Segmentfile) #reads the file at a given path
nysegments=Segments['Segments']['nysegments']
nxsegments=Segments['Segments']['nxsegments']
nacross=Segments['Segments']['nacross']
ndown=Segments['Segments']['ndown']
nxstart=Segments['Segments']['nxstart']
ny1start=Segments['Segments']['ny1start']
ny2start = ny1start+ndown 
nx1list = []; nx2list = []
ny1list = []; ny2list = []
for ix in range(nxsegments):
    nx1start = nxstart+ix*nacross; nx2start = nxstart+(ix+1)*nacross 
    for i in range(nysegments):
        nx1list.append(nx1start); nx2list.append(nx2start)
        ny1list.append(ny1start+i*ndown); ny2list.append(ny2start+i*ndown)
nsegments = nxsegments*nysegments

# Set up sub-grids in case of multiple segments
nyxgrid = []
for i in range(nsegments):
    nyxgridi = [ (y, x) for y in range(ny1list[i], ny2list[i]+1) for x in range(nx1list[i], nx2list[i]+1) ]
    nyxgrid.append(nyxgridi)

# Add the segments
draw = PIL.ImageDraw.Draw(im)
for i in range(nsegments):
    nx1 = nx1list[i]
    nx2 = nx2list[i]
    ny1 = ny1list[i]
    ny2 = ny2list[i]
    ims.myrectangle(draw,(nx1,ny1),(nx2,ny2),2)

# Show it
plt.figure()
plt.show(im,cmap = 'Greys_r', vmin = 0,vmax = 255)
im.show() # This shouldn't be necessary but there seems to be a bug with plt.show

# Save a copy
im.save(SEMSegmentjpgfile)
# Out:
# <img src="data:image/png;base64,..." width="852.75">

# %%
# Read and unpack the calibration data

# Just echo input data files  
print(Calibrationfile)

# Extract
Calibration=f90nml.read(Calibrationfile) #reads the file at a given path
pA=Calibration['Calibration']['pA']
pB=Calibration['Calibration']['pB']
pC=Calibration['Calibration']['pC']
pD=Calibration['Calibration']['pD']
# Out:
# ../case4.2 (calibration)/Calibration.nml

# %%
# Set up a grid of surface normal vectors and the backscatter response on them
nptsx = 103
nptsy = 101
nxmid = int(nptsx/2); #print nxmid
nymid = int(nptsy/2); #print nymid
nmax = 5
nxi = np.linspace(-nmax,nmax,nptsx); dnx = nxi[1]-nxi[0]
nyi = np.linspace(-nmax,nmax,nptsy); dny = nyi[1]-nyi[0]
nxigrid,nyigrid = np.meshgrid(nxi,nyi)
theta = 15*np.pi/180
sA = (-nxigrid*np.sin(theta)+np.cos(theta)-1)/(1+nxigrid**2+nyigrid**2)**.5
sB = (-nyigrid*np.sin(theta)+np.cos(theta)-1)/(1+nxigrid**2+nyigrid**2)**.5
sC = (+nxigrid*np.sin(theta)+np.cos(theta)-1)/(1+nxigrid**2+nyigrid**2)**.5
sD = (+nyigrid*np.sin(theta)+np.cos(theta)-1)/(1+nxigrid**2+nyigrid**2)**.5

# Set up the grids     
BSgridA = np.polyval(pA,sA)
BSgridB = np.polyval(pB,sB)
BSgridC = np.polyval(pC,sC)
BSgridD = np.polyval(pD,sD)

# %%
# Generating the response function for each detector
BSgridN = [BSgridA, BSgridB, BSgridC, BSgridD]
BSgridL = ['A', 'B', 'C', 'D']
BSmax = 150 # this for display purposes
nxigrid.shape
# Out:
# (101, 103)

# %%
# Set up interpolators for detector responses
Arule, Brule, Crule, Drule, \
KAxrule, KAyrule, KBxrule, KByrule, KCxrule, KCyrule, KDxrule, KDyrule =\
fbs.setupdetectorresponse2(BSgridA, BSgridB, BSgridC, BSgridD, nxi, nyi, dnx, dny)

# %%
# Create a blank slate
solution = np.zeros(cA.shape)

# %%
# Generic retrieval parameters
maxiter = 5
tolerance = 10

# %%
# Create the a priori/solution set, and the uncertainty set
    
# Define the variance in the observations (BS units^2)
noiseamp = 5.0
print('Std deviation in input signal is', noiseamp**.5)

# Define parameters determining the variance in the a priori (microns^2)
apriorivar0 = 225.0

print('Std deviation in a priori is', apriorivar0**.5)

# Create the initial a priori variance
apriorivar = np.ones(cA.shape)*apriorivar0

# Create the initial a priori set
aprioriset = np.zeros(cA.shape)
# Out:
# Std deviation in input signal is 2.23606797749979
# Std deviation in a priori is 15.0

# %%
# Loop to retrieve each segment
for isegment in range(nsegments):
    
    # Choose the particular location of the dataset to analyze
    nx1=nx1list[isegment]; nx2=nx2list[isegment]; nx = nx2-nx1+1
    ny1=ny1list[isegment]; ny2=ny2list[isegment]; ny = ny2-ny1+1

    # Construct gradients
    Ny_unscaled, Nx_unscaled = gds.makeNxNy(ny,nx)
    Ny = Ny_unscaled/dy
    Nx = -Nx_unscaled/dx #fixing x inversion
    
    # Number of observations
    nobs = (nx-1)*(ny-1)*4

    # Number of desired points (heights)
    nzpts = ny*nx-1
    
    # Extract the a priori variance
    vartemp = apriorivar[ny1:ny2+1,nx1:nx2+1]
    vartemp_long = np.reshape(vartemp,nzpts+1,0)
    Sa = np.diag(vartemp_long[:-1]); #print "apriorivar", shape(Sa)
    
    # Extract the starting z
    settemp = solution[ny1:ny2+1,nx1:nx2+1]
    settemp_long = np.reshape(settemp,nzpts+1,0)
    settemp_longminus1 = settemp_long[:-1]
    z_start = np.matrix(settemp_longminus1).T; #print "aprioriset", shape(z_start)
    z_start = z_start*0.0; #print "aprioriset", shape(z_start)

    # Construct the variance in observation + model
    Se = np.matrix(np.eye(nobs))*noiseamp # Variance in observation + model (c)

    # Do the retrieval
    print('')
    print("for", nx1, ny1)
    print("Segment:", isegment+1, "of", nsegments)
    z_retrieved = fbs.retrievesegment(\
        nx1,ny1,nx2,ny2,cA,cB,cC,cD,\
        Sa,Se,z_start,maxiter,tolerance,\
        Nx,Ny,\
        Arule, Brule, Crule, Drule,\
        KAxrule, KAyrule, \
        KBxrule, KByrule, \
        KCxrule, KCyrule, \
        KDxrule, KDyrule)
    
    if isegment == 0:
        solution[ny1:ny2+1,nx1:nx2+1] = copy.copy(z_retrieved)
    else:
        nextsolution = np.zeros(cA.shape)
        nextsolution[ny1:ny2+1,nx1:nx2+1] = copy.copy(z_retrieved)
        overlap = []
        for i in range(isegment):
            nextoverlap = list( set(nyxgrid[i])&set(nyxgrid[isegment]) )
            overlap = overlap + nextoverlap
            Noverlap = len(overlap); 
        print("Noverlap =", Noverlap)
        diff = 0.0
        for j in range(Noverlap):
            diff += nextsolution[overlap[j]] - solution[overlap[j]]
        diffavg = diff/Noverlap
        z_retrieved -= diffavg
        solution[ny1:ny2+1,nx1:nx2+1] = copy.copy(z_retrieved)
# Out:
# for 50 50
# Segment: 1 of 80
# statistics of observed intensities (detector B):
# mean = 64.46125
# max = 77.0
# min = 54.0
# iteration, di2 0 [[29978.7976558]]
# iteration, di2 1 [[67.58854655]]
# iteration, di2 2 [[1.01944502]]
#
# for 50 90
# Segment: 2 of 80
# statistics of observed intensities (detector B):
# mean = 67.236875
# max = 83.0
# min = 55.0
# iteration, di2 0 [[16407.06589773]]
# iteration, di2 1 [[48.03559635]]
# iteration, di2 2 [[0.61767816]]
# Noverlap = 41
#
# for 50 130
# Segment: 3 of 80
# statistics of observed intensities (detector B):
# mean = 69.678125
# max = 91.0
# min = 53.0
# iteration, di2 0 [[12667.0259474]]
# iteration, di2 1 [[34.65814374]]
# iteration, di2 2 [[0.37059945]]
# Noverlap = 41
#
# for 50 170
# Segment: 4 of 80
# statistics of observed intensities (detector B):
# mean = 74.471875
# max = 90.0
# min = 58.0
# iteration, di2 0 [[13508.87691141]]
# iteration, di2 1 [[39.17681469]]
# iteration, di2 2 [[0.34612067]]
# Noverlap = 41
#
# for 50 210
# Segment: 5 of 80
# statistics of observed intensities (detector B):
# mean = 78.385
# max = 95.0
# min = 64.0
# iteration, di2 0 [[23370.81644827]]
# iteration, di2 1 [[41.60643065]]
# iteration, di2 2 [[0.2545868]]
# Noverlap = 41
#
# for 50 250
# Segment: 6 of 80
# statistics of observed intensities (detector B):
# mean = 79.825
# max = 102.0
# min = 65.0
# iteration, di2 0 [[26955.49099901]]
# iteration, di2 1 [[38.00286749]]
# iteration, di2 2 [[0.17315108]]
# Noverlap = 41
#
# for 50 290
# Segment: 7 of 80
# statistics of observed intensities (detector B):
# mean = 82.365
# max = 106.0
# min = 68.0
# iteration, di2 0 [[42766.93385015]]
# iteration, di2 1 [[44.62536557]]
# iteration, di2 2 [[0.12856796]]
# Noverlap = 41
#
# for 50 330
# Segment: 8 of 80
# statistics of observed intensities (detector B):
# mean = 84.780625
# max = 108.0
# min = 70.0
# iteration, di2 0 [[55766.15827716]]
# iteration, di2 1 [[81.77624861]]
# iteration, di2 2 [[0.1824816]]
# Noverlap = 41
#
# for 90 50
# Segment: 9 of 80
# statistics of observed intensities (detector B):
# mean = 64.92
# max = 81.0
# min = 54.0
# iteration, di2 0 [[21380.45682727]]
# iteration, di2 1 [[76.83385634]]
# iteration, di2 2 [[1.34649784]]
# Noverlap = 42
#
# for 90 90
# Segment: 10 of 80
# statistics of observed intensities (detector B):
# mean = 66.540625
# max = 87.0
# min = 56.0
# iteration, di2 0 [[16621.71266462]]
# iteration, di2 1 [[52.9796547]]
# iteration, di2 2 [[0.73589498]]
# Noverlap = 84
#
# for 90 130
# Segment: 11 of 80
# statistics of observed intensities (detector B):
# mean = 67.760625
# max = 87.0
# min = 55.0
# iteration, di2 0 [[17026.13257815]]
# iteration, di2 1 [[44.8080698]]
# iteration, di2 2 [[0.51386066]]
# Noverlap = 84
#
# for 90 170
# Segment: 12 of 80
# statistics of observed intensities (detector B):
# mean = 73.681875
# max = 91.0
# min = 58.0
# iteration, di2 0 [[11432.90559333]]
# iteration, di2 1 [[36.69944295]]
# iteration, di2 2 [[0.30135742]]
# Noverlap = 84
#
# for 90 210
# Segment: 13 of 80
# statistics of observed intensities (detector B):
# mean = 78.1825
# max = 96.0
# min = 62.0
# iteration, di2 0 [[30309.36955015]]
# iteration, di2 1 [[51.17512611]]
# iteration, di2 2 [[0.37066233]]
# Noverlap = 84
#
# for 90 250
# Segment: 14 of 80
# statistics of observed intensities (detector B):
# mean = 79.763125
# max = 98.0
# min = 65.0
# iteration, di2 0 [[36673.75758215]]
# iteration, di2 1 [[40.98456527]]
# iteration, di2 2 [[0.21010588]]
# Noverlap = 84
#
# for 90 290
# Segment: 15 of 80
# statistics of observed intensities (detector B):
# mean = 81.92375
# max = 102.0
# min = 66.0
# iteration, di2 0 [[42837.77155243]]
# iteration, di2 1 [[38.57588339]]
# iteration, di2 2 [[0.14084495]]
# Noverlap = 84
#
# for 90 330
# Segment: 16 of 80
# statistics of observed intensities (detector B):
# mean = 83.6075
# max = 104.0
# min = 68.0
# iteration, di2 0 [[46658.03839879]]
# iteration, di2 1 [[50.66625204]]
# iteration, di2 2 [[0.18209131]]
# Noverlap = 83
#
# for 130 50
# Segment: 17 of 80
# statistics of observed intensities (detector B):
# mean = 64.484375
# max = 78.0
# min = 51.0
# iteration, di2 0 [[26606.00239073]]
# iteration, di2 1 [[76.92272365]]
# iteration, di2 2 [[1.46741817]]
# Noverlap = 42
#
# for 130 90
# Segment: 18 of 80
# statistics of observed intensities (detector B):
# mean = 65.43875
# max = 79.0
# min = 54.0
# iteration, di2 0 [[20220.4980089]]
# iteration, di2 1 [[65.73202167]]
# iteration, di2 2 [[0.99645063]]
# Noverlap = 84
#
# for 130 130
# Segment: 19 of 80
# statistics of observed intensities (detector B):
# mean = 67.78
# max = 86.0
# min = 53.0
# iteration, di2 0 [[17723.26180013]]
# iteration, di2 1 [[42.79194698]]
# iteration, di2 2 [[0.57567434]]
# Noverlap = 84
#
# for 130 170
# Segment: 20 of 80
# statistics of observed intensities (detector B):
# mean = 72.640625
# max = 89.0
# min = 58.0
# iteration, di2 0 [[12260.76197533]]
# iteration, di2 1 [[33.49209317]]
# iteration, di2 2 [[0.35850881]]
# Noverlap = 84
#
# for 130 210
# Segment: 21 of 80
# statistics of observed intensities (detector B):
# mean = 75.89125
# max = 94.0
# min = 63.0
# iteration, di2 0 [[16519.15058447]]
# iteration, di2 1 [[36.47326877]]
# iteration, di2 2 [[0.31347697]]
# Noverlap = 84
#
# for 130 250
# Segment: 22 of 80
# statistics of observed intensities (detector B):
# mean = 79.80125
# max = 100.0
# min = 65.0
# iteration, di2 0 [[34167.65497192]]
# iteration, di2 1 [[47.2372598]]
# iteration, di2 2 [[0.29498079]]
# Noverlap = 84
#
# for 130 290
# Segment: 23 of 80
# statistics of observed intensities (detector B):
# mean = 82.01
# max = 104.0
# min = 65.0
# iteration, di2 0 [[49987.86305064]]
# iteration, di2 1 [[67.61303103]]
# iteration, di2 2 [[0.33116324]]
# Noverlap = 84
#
# for 130 330
# Segment: 24 of 80
# statistics of observed intensities (detector B):
# mean = 84.889375
# max = 104.0
# min = 69.0
# iteration, di2 0 [[65624.01806591]]
# iteration, di2 1 [[131.24612136]]
# iteration, di2 2 [[0.68995914]]
# Noverlap = 83
#
# for 170 50
# Segment: 25 of 80
# statistics of observed intensities (detector B):
# mean = 63.274375
# max = 76.0
# min = 51.0
# iteration, di2 0 [[33242.68431763]]
# iteration, di2 1 [[92.43426824]]
# iteration, di2 2 [[2.01637298]]
# Noverlap = 42
#
# for 170 90
# Segment: 26 of 80
# statistics of observed intensities (detector B):
# mean = 65.530625
# max = 81.0
# min = 55.0
# iteration, di2 0 [[31344.35859122]]
# iteration, di2 1 [[56.38912186]]
# iteration, di2 2 [[0.9629959]]
# Noverlap = 84
#
# for 170 130
# Segment: 27 of 80
# statistics of observed intensities (detector B):
# mean = 68.43625
# max = 83.0
# min = 57.0
# iteration, di2 0 [[21373.97932988]]
# iteration, di2 1 [[43.58098112]]
# iteration, di2 2 [[0.62310861]]
# Noverlap = 84
#
# for 170 170
# Segment: 28 of 80
# statistics of observed intensities (detector B):
# mean = 71.375625
# max = 86.0
# min = 58.0
# iteration, di2 0 [[15854.60132751]]
# iteration, di2 1 [[30.20629864]]
# iteration, di2 2 [[0.36545829]]
# Noverlap = 84
#
# for 170 210
# Segment: 29 of 80
# statistics of observed intensities (detector B):
# mean = 75.24125
# max = 91.0
# min = 63.0
# iteration, di2 0 [[17505.29719964]]
# iteration, di2 1 [[33.64736166]]
# iteration, di2 2 [[0.38410854]]
# Noverlap = 84
#
# for 170 250
# Segment: 30 of 80
# statistics of observed intensities (detector B):
# mean = 77.115
# max = 92.0
# min = 62.0
# iteration, di2 0 [[19950.28958793]]
# iteration, di2 1 [[31.00540236]]
# iteration, di2 2 [[0.22069193]]
# Noverlap = 84
#
# for 170 290
# Segment: 31 of 80
# statistics of observed intensities (detector B):
# mean = 81.360625
# max = 100.0
# min = 66.0
# iteration, di2 0 [[36237.81586415]]
# iteration, di2 1 [[54.43149662]]
# iteration, di2 2 [[0.30363224]]
# Noverlap = 84
#
# for 170 330
# Segment: 32 of 80
# statistics of observed intensities (detector B):
# mean = 84.653125
# max = 105.0
# min = 68.0
# iteration, di2 0 [[55412.27828773]]
# iteration, di2 1 [[161.81696019]]
# iteration, di2 2 [[0.81487229]]
# Noverlap = 83
#
# for 210 50
# Segment: 33 of 80
# statistics of observed intensities (detector B):
# mean = 63.644375
# max = 77.0
# min = 53.0
# iteration, di2 0 [[46913.53983924]]
# iteration, di2 1 [[75.60351782]]
# iteration, di2 2 [[1.73525107]]
# Noverlap = 42
#
# for 210 90
# Segment: 34 of 80
# statistics of observed intensities (detector B):
# mean = 65.66125
# max = 79.0
# min = 54.0
# iteration, di2 0 [[37583.10409375]]
# iteration, di2 1 [[64.20682135]]
# iteration, di2 2 [[1.32840191]]
# Noverlap = 84
#
# for 210 130
# Segment: 35 of 80
# statistics of observed intensities (detector B):
# mean = 67.77125
# max = 83.0
# min = 56.0
# iteration, di2 0 [[31355.81875158]]
# iteration, di2 1 [[45.93953621]]
# iteration, di2 2 [[0.82339872]]
# Noverlap = 84
#
# for 210 170
# Segment: 36 of 80
# statistics of observed intensities (detector B):
# mean = 71.245
# max = 87.0
# min = 58.0
# iteration, di2 0 [[25307.49111816]]
# iteration, di2 1 [[36.69449963]]
# iteration, di2 2 [[0.48020857]]
# Noverlap = 84
#
# for 210 210
# Segment: 37 of 80
# statistics of observed intensities (detector B):
# mean = 74.0425
# max = 94.0
# min = 58.0
# iteration, di2 0 [[23508.55313331]]
# iteration, di2 1 [[35.46722166]]
# iteration, di2 2 [[0.3491072]]
# Noverlap = 84
#
# for 210 250
# Segment: 38 of 80
# statistics of observed intensities (detector B):
# mean = 77.161875
# max = 94.0
# min = 64.0
# iteration, di2 0 [[27481.51516881]]
# iteration, di2 1 [[38.00024442]]
# iteration, di2 2 [[0.27900466]]
# Noverlap = 84
#
# for 210 290
# Segment: 39 of 80
# statistics of observed intensities (detector B):
# mean = 80.738125
# max = 99.0
# min = 65.0
# iteration, di2 0 [[40742.61772246]]
# iteration, di2 1 [[95.20601832]]
# iteration, di2 2 [[0.43769069]]
# Noverlap = 84
#
# for 210 330
# Segment: 40 of 80
# statistics of observed intensities (detector B):
# mean = 83.4225
# max = 104.0
# min = 69.0
# iteration, di2 0 [[47326.64835635]]
# iteration, di2 1 [[151.11061388]]
# iteration, di2 2 [[0.82383901]]
# Noverlap = 83
#
# for 250 50
# Segment: 41 of 80
# statistics of observed intensities (detector B):
# mean = 63.691875
# max = 81.0
# min = 52.0
# iteration, di2 0 [[65184.20182024]]
# iteration, di2 1 [[77.39869398]]
# iteration, di2 2 [[1.73376455]]
# Noverlap = 42
#
# for 250 90
# Segment: 42 of 80
# statistics of observed intensities (detector B):
# mean = 64.949375
# max = 81.0
# min = 54.0
# iteration, di2 0 [[54677.88999089]]
# iteration, di2 1 [[55.33281132]]
# iteration, di2 2 [[1.09833169]]
# Noverlap = 84
#
# for 250 130
# Segment: 43 of 80
# statistics of observed intensities (detector B):
# mean = 67.79875
# max = 85.0
# min = 57.0
# iteration, di2 0 [[41619.37667587]]
# iteration, di2 1 [[47.26640535]]
# iteration, di2 2 [[0.81310386]]
# Noverlap = 84
#
# for 250 170
# Segment: 44 of 80
# statistics of observed intensities (detector B):
# mean = 70.229375
# max = 89.0
# min = 59.0
# iteration, di2 0 [[34007.59486817]]
# iteration, di2 1 [[38.52770481]]
# iteration, di2 2 [[0.46989365]]
# Noverlap = 84
#
# for 250 210
# Segment: 45 of 80
# statistics of observed intensities (detector B):
# mean = 73.924375
# max = 92.0
# min = 62.0
# iteration, di2 0 [[32639.84543922]]
# iteration, di2 1 [[39.64097725]]
# iteration, di2 2 [[0.53025016]]
# Noverlap = 84
#
# for 250 250
# Segment: 46 of 80
# statistics of observed intensities (detector B):
# mean = 76.780625
# max = 95.0
# min = 62.0
# iteration, di2 0 [[35553.57338204]]
# iteration, di2 1 [[44.83847137]]
# iteration, di2 2 [[0.39828998]]
# Noverlap = 84
#
# for 250 290
# Segment: 47 of 80
# statistics of observed intensities (detector B):
# mean = 80.274375
# max = 106.0
# min = 64.0
# iteration, di2 0 [[44142.40612355]]
# iteration, di2 1 [[106.73540012]]
# iteration, di2 2 [[0.66466833]]
# Noverlap = 84
#
# for 250 330
# Segment: 48 of 80
# statistics of observed intensities (detector B):
# mean = 84.444375
# max = 103.0
# min = 66.0
# iteration, di2 0 [[64460.88394248]]
# iteration, di2 1 [[269.37778643]]
# iteration, di2 2 [[1.45814784]]
# Noverlap = 83
#
# for 290 50
# Segment: 49 of 80
# statistics of observed intensities (detector B):
# mean = 63.475
# max = 77.0
# min = 52.0
# iteration, di2 0 [[77780.63821326]]
# iteration, di2 1 [[70.32078917]]
# iteration, di2 2 [[1.51793044]]
# Noverlap = 42
#
# for 290 90
# Segment: 50 of 80
# statistics of observed intensities (detector B):
# mean = 63.66625
# max = 79.0
# min = 53.0
# iteration, di2 0 [[80038.06875266]]
# iteration, di2 1 [[69.20750385]]
# iteration, di2 2 [[0.89515429]]
# Noverlap = 84
#
# for 290 130
# Segment: 51 of 80
# statistics of observed intensities (detector B):
# mean = 67.51875
# max = 87.0
# min = 52.0
# iteration, di2 0 [[56350.13458709]]
# iteration, di2 1 [[54.6484284]]
# iteration, di2 2 [[0.68870225]]
# Noverlap = 84
#
# for 290 170
# Segment: 52 of 80
# statistics of observed intensities (detector B):
# mean = 70.248125
# max = 87.0
# min = 55.0
# iteration, di2 0 [[43042.64258142]]
# iteration, di2 1 [[44.43216053]]
# iteration, di2 2 [[0.58807045]]
# Noverlap = 84
#
# for 290 210
# Segment: 53 of 80
# statistics of observed intensities (detector B):
# mean = 73.47
# max = 89.0
# min = 61.0
# iteration, di2 0 [[43550.5215294]]
# iteration, di2 1 [[40.87357242]]
# iteration, di2 2 [[0.47651213]]
# Noverlap = 84
#
# for 290 250
# Segment: 54 of 80
# statistics of observed intensities (detector B):
# mean = 76.261875
# max = 93.0
# min = 60.0
# iteration, di2 0 [[45673.50545028]]
# iteration, di2 1 [[51.04205666]]
# iteration, di2 2 [[0.29765613]]
# Noverlap = 84
#
# for 290 290
# Segment: 55 of 80
# statistics of observed intensities (detector B):
# mean = 80.109375
# max = 98.0
# min = 67.0
# iteration, di2 0 [[54978.58873703]]
# iteration, di2 1 [[127.71685087]]
# iteration, di2 2 [[0.57943318]]
# Noverlap = 84
#
# for 290 330
# Segment: 56 of 80
# statistics of observed intensities (detector B):
# mean = 83.699375
# max = 104.0
# min = 71.0
# iteration, di2 0 [[75768.47986354]]
# iteration, di2 1 [[344.01445556]]
# iteration, di2 2 [[1.77271717]]
# Noverlap = 83
#
# for 330 50
# Segment: 57 of 80
# statistics of observed intensities (detector B):
# mean = 63.113125
# max = 79.0
# min = 52.0
# iteration, di2 0 [[89574.4859008]]
# iteration, di2 1 [[74.80435628]]
# iteration, di2 2 [[1.58897973]]
# Noverlap = 42
#
# for 330 90
# Segment: 58 of 80
# statistics of observed intensities (detector B):
# mean = 64.08625
# max = 76.0
# min = 53.0
# iteration, di2 0 [[99471.30887946]]
# iteration, di2 1 [[139.49862858]]
# iteration, di2 2 [[1.42953547]]
# Noverlap = 84
#
# for 330 130
# Segment: 59 of 80
# statistics of observed intensities (detector B):
# mean = 65.729375
# max = 80.0
# min = 54.0
# iteration, di2 0 [[91337.36751586]]
# iteration, di2 1 [[151.02428745]]
# iteration, di2 2 [[1.21675669]]
# Noverlap = 84
#
# for 330 170
# Segment: 60 of 80
# statistics of observed intensities (detector B):
# mean = 69.5025
# max = 88.0
# min = 55.0
# iteration, di2 0 [[62393.66674103]]
# iteration, di2 1 [[60.76058592]]
# iteration, di2 2 [[0.54960186]]
# Noverlap = 84
#
# for 330 210
# Segment: 61 of 80
# statistics of observed intensities (detector B):
# mean = 73.34
# max = 87.0
# min = 60.0
# iteration, di2 0 [[53755.19209147]]
# iteration, di2 1 [[55.16715097]]
# iteration, di2 2 [[0.49226648]]
# Noverlap = 84
#
# for 330 250
# Segment: 62 of 80
# statistics of observed intensities (detector B):
# mean = 76.24
# max = 92.0
# min = 62.0
# iteration, di2 0 [[60118.15176784]]
# iteration, di2 1 [[95.94001896]]
# iteration, di2 2 [[0.53252617]]
# Noverlap = 84
#
# for 330 290
# Segment: 63 of 80
# statistics of observed intensities (detector B):
# mean = 79.875625
# max = 97.0
# min = 67.0
# iteration, di2 0 [[73410.34112824]]
# iteration, di2 1 [[267.16395594]]
# iteration, di2 2 [[1.35225954]]
# Noverlap = 84
#
# for 330 330
# Segment: 64 of 80
# statistics of observed intensities (detector B):
# mean = 84.03375
# max = 103.0
# min = 70.0
# iteration, di2 0 [[97724.85833534]]
# iteration, di2 1 [[766.41970866]]
# iteration, di2 2 [[6.2031325]]
# Noverlap = 83
#
# for 370 50
# Segment: 65 of 80
# statistics of observed intensities (detector B):
# mean = 63.960625
# max = 76.0
# min = 54.0
# iteration, di2 0 [[92035.41313639]]
# iteration, di2 1 [[67.01279946]]
# iteration, di2 2 [[1.66301793]]
# Noverlap = 42
#
# for 370 90
# Segment: 66 of 80
# statistics of observed intensities (detector B):
# mean = 64.341875
# max = 78.0
# min = 54.0
# iteration, di2 0 [[102847.85870681]]
# iteration, di2 1 [[148.4691632]]
# iteration, di2 2 [[1.72404111]]
# Noverlap = 84
#
# for 370 130
# Segment: 67 of 80
# statistics of observed intensities (detector B):
# mean = 64.916875
# max = 80.0
# min = 53.0
# iteration, di2 0 [[113659.47608126]]
# iteration, di2 1 [[312.93930628]]
# iteration, di2 2 [[2.46221241]]
# Noverlap = 84
#
# for 370 170
# Segment: 68 of 80
# statistics of observed intensities (detector B):
# mean = 67.82
# max = 88.0
# min = 53.0
# iteration, di2 0 [[90769.40117484]]
# iteration, di2 1 [[270.54358913]]
# iteration, di2 2 [[1.49486749]]
# Noverlap = 84
#
# for 370 210
# Segment: 69 of 80
# statistics of observed intensities (detector B):
# mean = 74.246875
# max = 92.0
# min = 59.0
# iteration, di2 0 [[82978.55944494]]
# iteration, di2 1 [[373.97626107]]
# iteration, di2 2 [[2.63820314]]
# Noverlap = 84
#
# for 370 250
# Segment: 70 of 80
# statistics of observed intensities (detector B):
# mean = 76.654375
# max = 92.0
# min = 63.0
# iteration, di2 0 [[84694.96811952]]
# iteration, di2 1 [[271.69370688]]
# iteration, di2 2 [[1.30852735]]
# Noverlap = 84
#
# for 370 290
# Segment: 71 of 80
# statistics of observed intensities (detector B):
# mean = 80.269375
# max = 103.0
# min = 64.0
# iteration, di2 0 [[103674.06300662]]
# iteration, di2 1 [[813.26091391]]
# iteration, di2 2 [[5.26782202]]
# Noverlap = 84
#
# for 370 330
# Segment: 72 of 80
# statistics of observed intensities (detector B):
# mean = 83.240625
# max = 103.0
# min = 69.0
# iteration, di2 0 [[112985.22537226]]
# iteration, di2 1 [[1178.17748509]]
# iteration, di2 2 [[12.37986925]]
# iteration, di2 3 [[0.75561658]]
# Noverlap = 83
#
# for 410 50
# Segment: 73 of 80
# statistics of observed intensities (detector B):
# mean = 64.704375
# max = 77.0
# min = 52.0
# iteration, di2 0 [[98490.10749842]]
# iteration, di2 1 [[71.37940619]]
# iteration, di2 2 [[1.96006743]]
# Noverlap = 42
#
# for 410 90
# Segment: 74 of 80
# statistics of observed intensities (detector B):
# mean = 64.7775
# max = 76.0
# min = 52.0
# iteration, di2 0 [[103191.70151652]]
# iteration, di2 1 [[95.30208142]]
# iteration, di2 2 [[1.44107498]]
# Noverlap = 84
#
# for 410 130
# Segment: 75 of 80
# statistics of observed intensities (detector B):
# mean = 65.988125
# max = 81.0
# min = 56.0
# iteration, di2 0 [[113862.20042058]]
# iteration, di2 1 [[217.63745331]]
# iteration, di2 2 [[1.89111085]]
# Noverlap = 84
#
# for 410 170
# Segment: 76 of 80
# statistics of observed intensities (detector B):
# mean = 67.87
# max = 86.0
# min = 53.0
# iteration, di2 0 [[145270.34331547]]
# iteration, di2 1 [[890.04446859]]
# iteration, di2 2 [[5.35412474]]
# Noverlap = 84
#
# for 410 210
# Segment: 77 of 80
# statistics of observed intensities (detector B):
# mean = 72.25
# max = 94.0
# min = 59.0
# iteration, di2 0 [[118831.06385045]]
# iteration, di2 1 [[677.60076226]]
# iteration, di2 2 [[3.716586]]
# Noverlap = 84
#
# for 410 250
# Segment: 78 of 80
# statistics of observed intensities (detector B):
# mean = 77.026875
# max = 100.0
# min = 64.0
# iteration, di2 0 [[125705.58803653]]
# iteration, di2 1 [[1004.63658557]]
# iteration, di2 2 [[7.39965627]]
# Noverlap = 84
#
# for 410 290
# Segment: 79 of 80
# statistics of observed intensities (detector B):
# mean = 79.990625
# max = 96.0
# min = 67.0
# iteration, di2 0 [[125669.40401569]]
# iteration, di2 1 [[1083.05974231]]
# iteration, di2 2 [[6.57393117]]
# Noverlap = 84
#
# for 410 330
# Segment: 80 of 80
# statistics of observed intensities (detector B):
# mean = 83.305
# max = 98.0
# min = 69.0
# iteration, di2 0 [[135587.19986504]]
# iteration, di2 1 [[1718.7502235]]
# iteration, di2 2 [[16.07183033]]
# iteration, di2 3 [[0.33962422]]
# Noverlap = 83

# %%
# Show the reconstructed surface
nx1tot = min(nx1list)
nx2tot = max(nx2list)
ny1tot = min(ny1list)
ny2tot = max(ny2list)
nxtot = nx2tot-nx1tot; print (nxtot)
nytot = ny2tot-ny1tot; print (nytot)
ymaxtot = (nytot-1)*dy; xmaxtot = (nxtot-1)*dx

surf_ytot = np.linspace(0,ymaxtot,nytot); #print surf_ytot[1]-surf_ytot[0]; 
surf_xtot = np.linspace(0,xmaxtot,nxtot); #print surf_xtot[1]-surf_xtot[0]; 
surf_xgridtot, surf_ygridtot = np.meshgrid(surf_xtot,surf_ytot)
settemp = solution[ny1tot:ny2tot,nx1tot:nx2tot]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(surf_xgridtot, surf_ygridtot, settemp, rstride=6,cstride=6)
ax.invert_yaxis() # invert y axis (this fixes the right-hand-oriented vs left-hand-oriented system)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title(imageroot)
ax.view_init(azim=-120,elev=22)
# Out:
# 400
# 320
# <img src="data:image/png;base64,..." width="480">

# %%
# Save this data

#save an image
fig.savefig(Retrievedjpgfile)


print("saving", Compressedfilename)
np.savez_compressed(Compressedfilename, \
                    surfaceroot=imageroot, \
                    imageroot=imageroot, \
                    nx1list=nx1list, \
                    nx2list=nx2list, \
                    ny1list=ny1list, \
                    ny2list=ny2list, \
                    pA=pA, \
                    pB=pB, \
                    pC=pC, \
                    pD=pD, \
                    sA=sA, \
                    sB=sB, \
                    sC=sC, \
                    sD=sD, \
                    nxi=nxi, \
                    nyi=nyi, \
                    dnx=dnx, \
                    dny=dny, \
                    solution=solution)
# Out:
# saving Segmentsretrieved
